# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)

# %%
def recur_Julia(z_plane, c, threshold=2, limit=1000):
    image = np.zeros(z_plane.shape)
    for [i, j], z in np.ndenumerate(z_plane):
        intensity = 0
        while (abs(z) < threshold) and (intensity < limit):
            z = z * z + c
            intensity += 1
        image[i, j] = intensity
    return image

# %%
width = 200
heigth = 200
a = np.arange(-1, 1, 2. / width)
b = -np.arange(-1, 1, 2. / heigth)
z_plane = np.array([np.complex(r, i) for i in b for r in a])
z_plane = z_plane.reshape(width, heigth)

# %%
img = recur_Julia(z_plane, c=- 0.8 + 0.156j, threshold=10)
#img = img * 255 / img.max()
fig = plt.figure()
fig.add_subplot(1, 2, 1)
plt.imshow(img, cmap=plt.cm.Greys_r)
fig.add_subplot(1, 2, 2)
plt.imshow(img)
plt.show()

# %%
t = np.array([[0.01+0.136j, 0.62 - 0.23j, 0.73 + 0.91j],[0.4, 0.53j, 0.26 + 0.29j],[0.47, 0.809 + 0.11j, 0.9j]])

# %%
for [i, j], n in np.ndenumerate(t):
    print i, j, n
# Out:
# 0 0 (1+1j)
# 0 1 (2+0j)
# 0 2 (3+0j)
# 1 0 (4+0j)
# 1 1 (5+0j)
# 1 2 (6+0j)
# 2 0 (7+0j)
# 2 1 (8+0j)
# 2 2 (9+0j)
